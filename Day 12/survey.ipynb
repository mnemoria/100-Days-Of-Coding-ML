# %%
import pandas as pd
import os

# %%
df_path = os.path.abspath("C:\\Users\\GRIZELLE\\GitHub Projects\\100-Days-Of-Coding-ML\\Datasets\\StackOverflow survey data\\survey_results_public.csv")

schema_df_path = os.path.abspath("C:\\Users\\GRIZELLE\\GitHub Projects\\100-Days-Of-Coding-ML\\Datasets\\StackOverflow survey data\\survey_results_schema.csv")

# %%
df = pd.read_csv(df_path, index_col='Respondent')
schema_df = pd.read_csv(schema_df_path, index_col='Column')

# %%
schema_df.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# ...                                                       ...      ...   ...
# 65586                          I am a developer by profession      Yes   NaN
# 65589                          I am a developer by profession      Yes   NaN
# 65602       I am not primarily a developer, but I write co...      Yes   NaN
# 65604                          I am a developer by profession       No   NaN
# 65617                          I am a developer by profession      Yes   NaN
#
# ...

# %%
df.loc[high_salary, ['Country', 'WebframeWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                     WebframeWorkedWith  \
# Respondent
# 8            United States                                  Flask
# 16          United Kingdom                        jQuery;React.js
# 17           United States  ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 18           United States                                    NaN
# 19           United States        Angular;Angular.js;ASP.NET Core
# ...                    ...                                    ...
# 65586        United States                                    NaN
# 65589        United States                                    NaN
# 65602        United States                                    NaN
# 65604        United States                                    NaN
# 65617              Germany                                    NaN
#
#             ConvertedComp
# Respondent
# 8                116000.0
# 16               108576.0
# 17                79000.0
# 18              1260000.0
# ...

# %%
countries = ['United Stets', 'India', 'United Kingdom', 'Germany', 'Canada']
country_filter = df['Country'].isin(countries)

# %%
df.loc[country_filter, 'Country']
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 6               Germany
# 7                 India
# 10       United Kingdom
#               ...
# 61490    United Kingdom
# 62464             India
# 62834            Canada
# 62954             India
# 64236             India
# Name: Country, Length: 18380, dtype: object

# %%
webframe_filter = df['WebframeWorkedWith'].str.contains('ASP.NET Core', na=False)

# %%
df.loc[webframe_filter, 'WebframeWorkedWith']
# Out:
# Respondent
# 1                                     ASP.NET;ASP.NET Core
# 19                         Angular;Angular.js;ASP.NET Core
# 21            Angular;ASP.NET Core;Express;React.js;Spring
# 49                                    ASP.NET;ASP.NET Core
# 58          Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
#                                ...
# 59168    Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 61111                         ASP.NET Core;Django;React.js
# 62954    ASP.NET;ASP.NET Core;Django;jQuery;Symfony;Vue.js
# 64567                                         ASP.NET Core
# 65112               Angular;Angular.js;ASP.NET Core;jQuery
# Name: WebframeWorkedWith, Length: 8082, dtype: object
