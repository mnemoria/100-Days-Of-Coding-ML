# %%
import pandas as pd
import numpy as np
import os

# %%
df_path = os.path.abspath("C:\\Users\\GRIZELLE\\GitHub Projects\\100-Days-Of-Coding-ML\\Datasets\\StackOverflow survey data\\survey_results_public.csv")

schema_df_path = os.path.abspath("C:\\Users\\GRIZELLE\\GitHub Projects\\100-Days-Of-Coding-ML\\Datasets\\StackOverflow survey data\\survey_results_schema.csv")

# %%
df = pd.read_csv(df_path, index_col='Respondent')
schema_df = pd.read_csv(schema_df_path, index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
column_names = list(df.columns.values)
print(column_names)
# Out:
# ['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith', 'MiscTechDesireNextYear', 'MiscTechWorkedWith', 'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps', 'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch', 'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms', 'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites', 'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear', 'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount', 'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength', 'Trans', 'UndergradMajor', 'WebframeDesireNextYear', 'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode', 'YearsCodePro']

# %%
df[column_names].select_dtypes(int).describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df[column_names].select_dtypes(int).describe()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py:10940, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10691 @final
#   10692 def describe(
#   10693     self: NDFrameT,
#    (...)
#   10697     datetime_is_numeric: bool_t = False,
#   10698 ) -> NDFrameT:
#   10699     """
#   10700     Generate descriptive statistics.
#   10701
#    (...)
#   10938     max            NaN      3.0
#   10939     """
# > 10940     return describe_ndframe(
#   10941         obj=self,
#   10942         include=include,
#   10943         exclude=exclude,
#   10944         datetime_is_numeric=datetime_is_numeric,
#   10945         percentiles=percentiles,
#   10946     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\describe.py:94, in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      89     describer = SeriesDescriber(
#      90         obj=cast("Series", obj),
#      91         datetime_is_numeric=datetime_is_numeric,
#      92     )
#      93 else:
# ---> 94     describer = DataFrameDescriber(
#      95         obj=cast("DataFrame", obj),
#      96         include=include,
#      97         exclude=exclude,
#      98         datetime_is_numeric=datetime_is_numeric,
#      99     )
#     101 result = describer.describe(percentiles=percentiles)
#     102 return cast(NDFrameT, result)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\describe.py:171, in DataFrameDescriber.__init__(self, obj, include, exclude, datetime_is_numeric)
#     168 self.exclude = exclude
#     170 if obj.ndim == 2 and obj.columns.size == 0:
# --> 171     raise ValueError("Cannot describe a DataFrame without columns")
#     173 super().__init__(obj, datetime_is_numeric=datetime_is_numeric)
#
# ValueError: Cannot describe a DataFrame without columns

# %%
# Chaining
(
    df
    [column_names]
    .describe()
)
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
# can comb08 be and int8
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
# Chaining
(
    df
    [column_names]
    .groupby('Country')
    .nunique()
)
# Out:
#                                       MainBranch  Hobbyist  Age  Age1stCode  \
# Country
# Afghanistan                                    5         2   10          17
# Albania                                        4         2   17          19
# Algeria                                        5         2   24          17
# Andorra                                        4         2    3           7
# Angola                                         5         2    3           4
# ...                                          ...       ...  ...         ...
# Venezuela, Bolivarian Republic of...           4         2   21          17
# Viet Nam                                       5         2   31          29
# Yemen                                          2         2    2           4
# Zambia                                         4         2    7           8
# Zimbabwe                                       4         2   11          11
#
#                                       CompFreq  CompTotal  ConvertedComp  \
# Country
# Afghanistan                                  3         22             21
# Albania                                      2         16             16
# Algeria                                      3         14             15
# Andorra                                      2          2              2
# Angola                                       3          3              2
# ...                                        ...        ...            ...
# Venezuela, Bolivarian Republic of...         3         24             25
# Viet Nam                                     3         66             68
# Yemen                                        1          1              1
# Zambia                                       3          5              5
# Zimbabwe                                     3         11             10
#
#                                       CurrencyDesc  CurrencySymbol  \
# Country
# Afghanistan                                      8               8
# Albania                                          6               6
# Algeria                                          4               4
# Andorra                                          5               5
# Angola                                           3               3
# ...                                            ...             ...
# Venezuela, Bolivarian Republic of...             3               3
# Viet Nam                                        12              12
# Yemen                                            1               1
# Zambia                                           2               2
# Zimbabwe                                         2               2
#
#                                       DatabaseDesireNextYear  \
# Country
# Afghanistan                                               29
# Albania                                                   33
# Algeria                                                   53
# Andorra                                                    7
# Angola                                                     4
# ...                                                      ...
# Venezuela, Bolivarian Republic of...                      49
# Viet Nam                                                 132
# Yemen                                                      7
# Zambia                                                    13
# Zimbabwe                                                  24
#
#                                       DatabaseWorkedWith  DevType  EdLevel  \
# Country
# Afghanistan                                           28       38        8
# Albania                                               31       34        6
# Algeria                                               46       37        8
# Andorra                                                8        7        5
# Angola                                                 2        3        4
# ...                                                  ...      ...      ...
# Venezuela, Bolivarian Republic of...                  43       46        8
# Viet Nam                                             134      115        9
# Yemen                                                  5        3        3
# Zambia                                                11       15        7
# Zimbabwe                                              21       18        5
#
#                                       Employment  Ethnicity  Gender  \
# Country
# Afghanistan                                    6         12       4
# Albania                                        5          3       2
# Algeria                                        6          9       3
# Andorra                                        4          2       1
# Angola                                         6          2       2
# ...                                          ...        ...     ...
# Venezuela, Bolivarian Republic of...           5         12       3
# Viet Nam                                       7         12       5
# Yemen                                          4          2       1
# Zambia                                         5          2       2
# Zimbabwe                                       6          1       1
#
#                                       JobFactors  JobSat  JobSeek  \
# Country
# Afghanistan                                   29       5        3
# Albania                                       24       5        3
# Algeria                                       40       5        3
# Andorra                                        3       5        2
# Angola                                         3       3        3
# ...                                          ...     ...      ...
# Venezuela, Bolivarian Republic of...          35       5        3
# Viet Nam                                      86       5        3
# Yemen                                          3       2        3
# Zambia                                        10       5        3
# Zimbabwe                                      18       5        3
#
#                                       LanguageDesireNextYear  \
# Country
# Afghanistan                                               38
# Albania                                                   37
# Algeria                                                   66
# Andorra                                                    6
# Angola                                                     4
# ...                                                      ...
# Venezuela, Bolivarian Republic of...                      55
# Viet Nam                                                 210
# Yemen                                                      7
# Zambia                                                    12
# Zimbabwe                                                  24
#
#                                       LanguageWorkedWith  \
# Country
# Afghanistan                                           42
# Albania                                               37
# Algeria                                               66
# Andorra                                                8
# Angola                                                 3
# ...                                                  ...
# Venezuela, Bolivarian Republic of...                  55
# Viet Nam                                             212
# Yemen                                                  6
# Zambia                                                14
# Zimbabwe                                              25
#
#                                       MiscTechDesireNextYear  \
# Country
# Afghanistan                                               22
# Albania                                                   27
# Algeria                                                   50
# Andorra                                                    5
# Angola                                                     3
# ...                                                      ...
# Venezuela, Bolivarian Republic of...                      48
# Viet Nam                                                 107
# Yemen                                                      5
# Zambia                                                    10
# Zimbabwe                                                  17
#
#                                       MiscTechWorkedWith  \
# Country
# Afghanistan                                           18
# Albania                                               20
# Algeria                                               30
# Andorra                                                8
# Angola                                                 2
# ...                                                  ...
# Venezuela, Bolivarian Republic of...                  25
# Viet Nam                                              73
# Yemen                                                  5
# Zambia                                                 7
# Zimbabwe                                              14
#
#                                       NEWCollabToolsDesireNextYear  \
# Country
# Afghanistan                                                     19
# Albania                                                         26
# Algeria                                                         41
# Andorra                                                          6
# Angola                                                           4
# ...                                                            ...
# Venezuela, Bolivarian Republic of...                            36
# Viet Nam                                                       114
# Yemen                                                            4
# Zambia                                                          12
# Zimbabwe                                                        22
#
#                                       NEWCollabToolsWorkedWith  NEWDevOps  \
# Country
# Afghanistan                                                 19          3
# Albania                                                     30          3
# Algeria                                                     28          3
# Andorra                                                      9          1
# Angola                                                       3          3
# ...                                                        ...        ...
# Venezuela, Bolivarian Republic of...                        33          3
# Viet Nam                                                   130          3
# Yemen                                                        4          2
# Zambia                                                       7          3
# Zimbabwe                                                    19          3
#
#                                       NEWDevOpsImpt  NEWEdImpt  NEWJobHunt  \
# Country
# Afghanistan                                       5          5          19
# Albania                                           5          5          24
# Algeria                                           5          5          29
# Andorra                                           3          3           3
# Angola                                            3          3           4
# ...                                             ...        ...         ...
# Venezuela, Bolivarian Republic of...              4          5          36
# Viet Nam                                          5          5          90
# Yemen                                             2          2           2
# Zambia                                            3          5           6
# Zimbabwe                                          5          5          17
#
#                                       NEWJobHuntResearch  NEWLearn  \
# Country
# Afghanistan                                           17         3
# Albania                                               17         4
# Algeria                                               23         4
# Andorra                                                3         4
# Angola                                                 3         2
# ...                                                  ...       ...
# Venezuela, Bolivarian Republic of...                  23         4
# Viet Nam                                              40         4
# Yemen                                                  2         2
# Zambia                                                 6         3
# Zimbabwe                                              17         3
#
#                                       NEWOffTopic  NEWOnboardGood  \
# Country
# Afghanistan                                     3               3
# Albania                                         3               3
# Algeria                                         3               3
# Andorra                                         3               3
# Angola                                          3               3
# ...                                           ...             ...
# Venezuela, Bolivarian Republic of...            3               3
# Viet Nam                                        3               3
# Yemen                                           2               1
# Zambia                                          3               3
# Zimbabwe                                        3               3
#
#                                       NEWOtherComms  NEWOvertime  \
# Country
# Afghanistan                                       2            5
# Albania                                           2            5
# Algeria                                           2            5
# Andorra                                           2            2
# Angola                                            2            3
# ...                                             ...          ...
# Venezuela, Bolivarian Republic of...              2            5
# Viet Nam                                          2            5
# Yemen                                             1            2
# Zambia                                            2            5
# Zimbabwe                                          2            5
#
#                                       NEWPurchaseResearch  NEWPurpleLink  \
# Country
# Afghanistan                                            16              4
# Albania                                                14              4
# Algeria                                                21              4
# Andorra                                                 6              2
# Angola                                                  3              3
# ...                                                   ...            ...
# Venezuela, Bolivarian Republic of...                   16              4
# Viet Nam                                               41              4
# Yemen                                                   5              3
# Zambia                                                  9              3
# Zimbabwe                                               16              4
#
#                                       NEWSOSites  NEWStuck  OpSys  OrgSize  \
# Country
# Afghanistan                                   15        29      3        9
# Albania                                       10        26      3        7
# Algeria                                       16        48      4        8
# Andorra                                        5         7      3        4
# Angola                                         5         3      2        3
# ...                                          ...       ...    ...      ...
# Venezuela, Bolivarian Republic of...           9        38      3        7
# Viet Nam                                      24        97      4        9
# Yemen                                          3         6      1        2
# Zambia                                         7        12      3        6
# Zimbabwe                                       8        20      3        6
#
#                                       PlatformDesireNextYear  \
# Country
# Afghanistan                                               24
# Albania                                                   35
# Algeria                                                   61
# Andorra                                                    8
# Angola                                                     5
# ...                                                      ...
# Venezuela, Bolivarian Republic of...                      54
# Viet Nam                                                 177
# Yemen                                                      7
# Zambia                                                    14
# Zimbabwe                                                  24
#
#                                       PlatformWorkedWith  PurchaseWhat  \
# Country
# Afghanistan                                           23             3
# Albania                                               34             3
# Algeria                                               47             3
# Andorra                                                9             3
# Angola                                                 3             2
# ...                                                  ...           ...
# Venezuela, Bolivarian Republic of...                  42             3
# Viet Nam                                             166             3
# Yemen                                                  6             2
# Zambia                                                11             2
# Zimbabwe                                              24             3
#
#                                       Sexuality  SOAccount  SOComm  \
# Country
# Afghanistan                                   5          3       6
# Albania                                       3          3       5
# Algeria                                       2          3       6
# Andorra                                       2          3       4
# Angola                                        2          1       4
# ...                                         ...        ...     ...
# Venezuela, Bolivarian Republic of...          4          3       6
# Viet Nam                                      5          3       6
# Yemen                                         1          1       1
# Zambia                                        2          2       5
# Zimbabwe                                      1          2       5
#
#                                       SOPartFreq  SOVisitFreq  SurveyEase  \
# Country
# Afghanistan                                    6            6           3
# Albania                                        5            4           2
# Algeria                                        5            5           3
# Andorra                                        2            2           2
# Angola                                         2            4           2
# ...                                          ...          ...         ...
# Venezuela, Bolivarian Republic of...           6            5           3
# Viet Nam                                       6            6           3
# Yemen                                          1            2           2
# Zambia                                         5            4           2
# Zimbabwe                                       5            5           2
#
#                                       SurveyLength  Trans  UndergradMajor  \
# Country
# Afghanistan                                      3      2               6
# Albania                                          3      2               6
# Algeria                                          3      1              10
# Andorra                                          2      1               4
# Angola                                           2      1               3
# ...                                            ...    ...             ...
# Venezuela, Bolivarian Republic of...             3      1               7
# Viet Nam                                         3      2              12
# Yemen                                            1      1               3
# Zambia                                           3      2               4
# Zimbabwe                                         2      1               5
#
#                                       WebframeDesireNextYear  \
# Country
# Afghanistan                                               30
# Albania                                                   26
# Algeria                                                   54
# Andorra                                                    8
# Angola                                                     3
# ...                                                      ...
# Venezuela, Bolivarian Republic of...                      50
# Viet Nam                                                 132
# Yemen                                                      6
# Zambia                                                    14
# Zimbabwe                                                  23
#
#                                       WebframeWorkedWith  WelcomeChange  \
# Country
# Afghanistan                                           23              5
# Albania                                               26              6
# Algeria                                               43              6
# Andorra                                                8              3
# Angola                                                 3              2
# ...                                                  ...            ...
# Venezuela, Bolivarian Republic of...                  47              6
# Viet Nam                                             136              6
# Yemen                                                  5              2
# Zambia                                                 9              5
# Zimbabwe                                              24              5
#
#                                       WorkWeekHrs  YearsCode  YearsCodePro
# Country
# Afghanistan                                    12         19            13
# Albania                                         7         12            14
# Algeria                                        13         17            13
# Andorra                                         3          6             6
# Angola                                          3          4             3
# ...                                           ...        ...           ...
# Venezuela, Bolivarian Republic of...           17         25            20
# Viet Nam                                       25         28            20
# Yemen                                           1          5             2
# Zambia                                          7         10             8
# Zimbabwe                                       10         11             8
#
# [183 rows x 59 columns]
