# %%
import pandas as pd
import os

# %%
path = os.path.abspath("C:\\Users\\GRIZELLE\\GitHub Projects\\100-Days-Of-Coding-ML\\Datasets\\Digimon dataset\\DigiDB_digimonlist.csv")

df = pd.read_csv(path)

# %%
df
# Out:
#      Number            Digimon Stage     Type Attribute  Memory  Equip Slots  \
# 0         1            Kuramon  Baby     Free   Neutral       2            0
# 1         2            Pabumon  Baby     Free   Neutral       2            0
# 2         3            Punimon  Baby     Free   Neutral       2            0
# 3         4            Botamon  Baby     Free   Neutral       2            0
# 4         5            Poyomon  Baby     Free   Neutral       2            0
# ..      ...                ...   ...      ...       ...     ...          ...
# 244     245         Valkyrimon  Mega     Free      Wind      18            3
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 246     247  MirageGaogamon BM  Mega     Data     Light      20            2
# 247     248         Ravemon BM  Mega  Vaccine      Wind      20            2
# 248     249         Rosemon BM  Mega     Data     Plant      20            2
#
# ...

# %%
df.shape
# Out:
# (249, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Number       249 non-null    int64
#  1   Digimon      249 non-null    object
#  2   Stage        249 non-null    object
#  3   Type         249 non-null    object
#  4   Attribute    249 non-null    object
#  5   Memory       249 non-null    int64
#  6   Equip Slots  249 non-null    int64
#  7   Lv 50 HP     249 non-null    int64
#  8   Lv50 SP      249 non-null    int64
#  9   Lv50 Atk     249 non-null    int64
#  10  Lv50 Def     249 non-null    int64
#  11  Lv50 Int     249 non-null    int64
#  12  Lv50 Spd     249 non-null    int64
# dtypes: int64(9), object(4)
# memory usage: 25.4+ KB

# %%
pd.set_option('display.max_columns', 10)

# %%
df.head()
# Out:
#    Number  Digimon Stage  Type Attribute  ...  Lv50 SP  Lv50 Atk  Lv50 Def  \
# 0       1  Kuramon  Baby  Free   Neutral  ...       77        79        69
# 1       2  Pabumon  Baby  Free   Neutral  ...       62        76        76
# 2       3  Punimon  Baby  Free   Neutral  ...       50        97        87
# 3       4  Botamon  Baby  Free   Neutral  ...       68        77        95
# 4       5  Poyomon  Baby  Free   Neutral  ...       98        54        59
#
#    Lv50 Int  Lv50 Spd
# 0        68        95
# 1        69        68
# 2        50        75
# 3        76        61
# 4        95        86
#
# [5 rows x 13 columns]

# %%
df.head(10)
# Out:
#    Number   Digimon        Stage  Type Attribute  ...  Lv50 SP  Lv50 Atk  \
# 0       1   Kuramon         Baby  Free   Neutral  ...       77        79
# 1       2   Pabumon         Baby  Free   Neutral  ...       62        76
# 2       3   Punimon         Baby  Free   Neutral  ...       50        97
# 3       4   Botamon         Baby  Free   Neutral  ...       68        77
# 4       5   Poyomon         Baby  Free   Neutral  ...       98        54
# 5       6   Koromon  In-Training  Free      Fire  ...       52       109
# 6       7   Tanemon  In-Training  Free     Plant  ...       64        85
# 7       8  Tsunomon  In-Training  Free     Earth  ...       54       107
# 8       9  Tsumemon  In-Training  Free      Dark  ...       64       108
# 9      10   Tokomon  In-Training  Free   Neutral  ...       86        76
#
#    Lv50 Def  Lv50 Int  Lv50 Spd
# 0        69        68        95
# 1        76        69        68
# 2        87        50        75
# 3        95        76        61
# ...

# %%
df.tail()
# Out:
#      Number            Digimon Stage     Type Attribute  ...  Lv50 SP  \
# 244     245         Valkyrimon  Mega     Free      Wind  ...      139
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire  ...      114
# 246     247  MirageGaogamon BM  Mega     Data     Light  ...      124
# 247     248         Ravemon BM  Mega  Vaccine      Wind  ...      133
# 248     249         Rosemon BM  Mega     Data     Plant  ...      143
#
#      Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 244       148       129       129       168
# 245       228       104        84       168
# 246       178       104       158       174
# 247       149       139       144       213
# 248       149       139       159       143
#
# [5 rows x 13 columns]
