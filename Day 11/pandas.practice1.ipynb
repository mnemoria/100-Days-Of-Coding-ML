# %%
# How to Set, Reset, and Use Indexes

import pandas as pd
import os

# %%
digimon_list = os.path.abspath("C:\\Users\\GRIZELLE\\GitHub Projects\\100-Days-Of-Coding-ML\\Datasets\\Digimon dataset\\DigiDB_digimonlist.csv")

move_list = os.path.abspath("C:\\Users\\GRIZELLE\\GitHub Projects\\100-Days-Of-Coding-ML\\Datasets\\Digimon dataset\\DigiDB_movelist.csv")

support_list = os.path.abspath("C:\\Users\\GRIZELLE\\GitHub Projects\\100-Days-Of-Coding-ML\\Datasets\\Digimon dataset\\DigiDB_supportlist.csv")

# %%
digimon_df = pd.read_csv(digimon_list, index_col='Number')
move_df = pd.read_csv(move_list)
support_df = pd.read_csv(support_list)

# %%
digimon_df.head()
# Out:
#         Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  Lv50 SP  \
# Number
# 1       Kuramon  Baby  Free   Neutral       2            0       590       77
# 2       Pabumon  Baby  Free   Neutral       2            0       950       62
# 3       Punimon  Baby  Free   Neutral       2            0       870       50
# 4       Botamon  Baby  Free   Neutral       2            0       690       68
# 5       Poyomon  Baby  Free   Neutral       2            0       540       98
#
#         Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# Number
# 1             79        69        68        95
# 2             76        76        69        68
# 3             97        87        50        75
# 4             77        95        76        61
# 5             54        59        95        86

# %%
digimon_df.loc[1]
# Out:
# Digimon        Kuramon
# Stage             Baby
# Type              Free
# Attribute      Neutral
# Memory               2
# Equip Slots          0
# Lv 50 HP           590
# Lv50 SP             77
# Lv50 Atk            79
# Lv50 Def            69
# Lv50 Int            68
# Lv50 Spd            95
# Name: 1, dtype: object

# %%
move_df.set_index('Move', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 move_df.set_index('Move', inplace=True)
#       2 move_df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
#    6011 if inplace:
#    6012     frame = self
#
# KeyError: "None of ['Move'] are in the columns"

# %%
move_df.sort_index(inplace=True)

# %%
move_df
# Out:
#                     SP Cost      Type  Power Attribute Inheritable  \
# Move
# Acceleration Boost        6   Support      0   Neutral         Yes
# Agility Charge            6   Support      0   Neutral         Yes
# Aguichant L\E8vres       30     Magic      0     Light          No
# Air Shot                  5     Magic     50      Wind          No
# Amethyst Mandala         20     Magic     70     Light          No
# ...                     ...       ...    ...       ...         ...
# Wolkenapalm II            6  Physical     85      Fire         Yes
# Wolkenapalm III           9  Physical    105      Fire         Yes
# Wyvern's Breath          25  Physical    110      Wind          No
# X-Aura                   25   Support      0   Neutral         Yes
# X-Heal                    8   Support      0   Neutral         Yes
#
#                                                           Description
# Move
# Acceleration Boost            Doubles damage output in the next turn.
# Agility Charge             Increases EVA of one battle member by 10%.
# Aguichant L\E8vres  INT-penetrating Light attack on one foe and ab...
# Air Shot            Magic attack, 50 Wind damage to one foe. 10% c...
# Amethyst Mandala    Magic attack, 70 Light damage to all foes. Can...
# ...                                                               ...
# Wolkenapalm II      Physical attack, 85 Fire damage to one foe. 95...
# Wolkenapalm III     Physical attack, 105 Fire damage to one foe. 9...
# Wyvern's Breath     Physical attack, 110 Wind damage to all foes. ...
# X-Aura                             Restores HP for all party members.
# X-Heal                              Restores HP for one party member.
#
# [387 rows x 6 columns]
